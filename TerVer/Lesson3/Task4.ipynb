# %%
from math import *

# %%
#В университет на факультеты A и B поступило равное количество студентов, 
#а на факультет C студентов поступило столько же, сколько на A и B вместе. 
#Вероятность того, что студент факультета A сдаст первую сессию, равна 0.8. 
#Для студента факультета B эта вероятность равна 0.7, а для студента факультета C - 0.9. 
#Студент сдал первую сессию. Какова вероятность, что он учится: 
#a). на факультете A б). на факультете B в). на факультете C?
Pa = 0.8
Pb = 0.7
Pc = 0.9
#Вероятность сдачи сессии всеми факультетами
Po = 1/4 * Pa + 1/4 * Pb + 1/2 * Pc
print(f'Студент учится на факультете A={Pa/Po/4:.4f}') #Расчет по формуле Байса
print(f'Студент учится на факультете B={Pb/Po/4:.4f}') #Расчет по формуле Байса
print(f'Студент учится на факультете C={Pc/Po/2:.4f}') #Расчет по формуле Байса
# Out:
# Студент учится на факультете A=0.2424
# Студент учится на факультете B=0.2121
# Студент учится на факультете C=0.5455
