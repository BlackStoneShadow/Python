# %%
#Когда используется критерий Стьюдента, а когда Z –критерий?
print(f'Критерий t-Стьюдента используется при соблюдении нормальности и равенстве дисперсий, а также неизвестной сигме генеральной совокупности')
print(f'Критерий Z используется при соблюдении нормальности и известной сигме генеральной совокупности')
# Out:
# Критерий t-Стьюдента используется при соблюдении нормальности и равенстве дисперсий, а также неизвестной сигме генеральной совокупности
# Критерий Z используется при соблюдении нормальности и известной сигме генеральной совокупности
